# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Préparation et chargement des données, describe du X_train

# %%
X_train_path = '../data/X_train_78VdSWL.csv'
Y_train_path = '../data/y_train_u0UkKEh.csv'
X_test_path = '../data/X_test_XKVc4no.csv'
Y_test_path =  '../data/new_output_sample.csv'

X_train_t = pd.read_csv(X_train_path)
X_test_t = pd.read_csv(X_test_path)
y_train_t = pd.read_csv(Y_train_path)
X_train_t.describe(include='all')
# Out:
#                    Horodate   5423908671   2568793410   8310762594  \
# count                  1057  1057.000000  1057.000000  1057.000000
# unique                 1057          NaN          NaN          NaN
# top     2023-01-31 00:00:00          NaN          NaN          NaN
# freq                      1          NaN          NaN          NaN
# mean                    NaN   567.010407     4.575213   814.052034
# std                     NaN   225.700515   117.691471   485.858805
# min                     NaN   143.000000     0.000000    23.000000
# 25%                     NaN   450.000000     0.000000   465.000000
# 50%                     NaN   526.000000     0.000000   802.000000
# 75%                     NaN   589.000000     0.000000  1111.000000
# max                     NaN  1766.000000  3785.000000  2213.000000
#
#          6235194807    423895617    193845276    216589743    218753964  \
# count   1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     375.370861  1202.364238   187.719016   554.808893    18.550615
# std      343.137069   345.274938    80.496774   278.262533    33.216826
# min       13.000000   201.000000    40.000000     0.000000     0.000000
# 25%       83.000000   980.000000   126.000000   333.000000     0.000000
# 50%      173.000000  1209.000000   177.000000   505.000000     2.000000
# 75%      672.000000  1425.000000   234.000000   714.000000    37.000000
# max     1195.000000  2390.000000   499.000000  1693.000000   776.000000
#
#          1794650328  ...  holed_991   holed_992   holed_993    holed_994  \
# count   1057.000000  ...      913.0  963.000000  928.000000   933.000000
# unique          NaN  ...        NaN         NaN         NaN          NaN
# top             NaN  ...        NaN         NaN         NaN          NaN
# freq            NaN  ...        NaN         NaN         NaN          NaN
# mean     265.464522  ...        0.0   23.493250   40.172414   587.293676
# std      228.233634  ...        0.0    8.952096   50.883271   427.655623
# min       60.000000  ...        0.0    9.000000    1.000000    10.000000
# 25%      116.000000  ...        0.0   18.000000   16.000000   162.000000
# 50%      163.000000  ...        0.0   21.000000   24.000000   530.000000
# 75%      335.000000  ...        0.0   25.000000   41.000000   948.000000
# max     1545.000000  ...        0.0  114.000000  410.000000  2134.000000
#
#         holed_995    holed_996   holed_997   holed_998   holed_999  holed_1000
# count       918.0   945.000000  986.000000  929.000000  968.000000  838.000000
# unique        NaN          NaN         NaN         NaN         NaN         NaN
# top           NaN          NaN         NaN         NaN         NaN         NaN
# freq          NaN          NaN         NaN         NaN         NaN         NaN
# mean          0.0  1096.756614  187.293103   64.487621  114.547521  295.560859
# std           0.0   436.254909  134.089130   37.826397  125.393007  101.077649
# min           0.0   341.000000   46.000000   14.000000    9.000000   66.000000
# 25%           0.0   650.000000  106.000000   41.000000   26.000000  222.250000
# 50%           0.0  1157.000000  130.000000   54.000000   42.000000  283.000000
# 75%           0.0  1398.000000  216.000000   71.000000  195.250000  347.000000
# max           0.0  2462.000000  854.000000  252.000000  703.000000  727.000000
#
# [11 rows x 21001 columns]

# %%
X_train=X_train_t.copy() 
X_test=X_test_t.copy()  
y_train=y_train_t.copy()

# %% [markdown]
# X_train head

# %%
X_train.head()
# Out:
#               Horodate  5423908671  2568793410  8310762594  6235194807  \
# 0  2023-01-09 00:00:00       352.0         0.0       371.0       110.0
# 1  2023-01-09 00:30:00       405.0         0.0       363.0       108.0
# 2  2023-01-09 01:00:00       599.0         0.0       352.0        93.0
# 3  2023-01-09 01:30:00       315.0         0.0       348.0        84.0
# 4  2023-01-09 02:00:00       448.0         0.0       364.0        73.0
#
#    423895617  193845276  216589743  218753964  1794650328  ...  holed_991  \
# 0      724.0      102.0      256.0        7.0       105.0  ...        0.0
# 1      478.0      147.0      281.0        8.0       134.0  ...        0.0
# 2      832.0      155.0      295.0        5.0        96.0  ...        0.0
# 3      574.0      152.0      267.0       15.0       156.0  ...        0.0
# 4      421.0      176.0      346.0       38.0        97.0  ...        0.0
#
#    holed_992  holed_993  holed_994  holed_995  holed_996  holed_997  \
# 0       32.0      152.0        NaN        0.0     1099.0      117.0
# 1       34.0       84.0        NaN        NaN      782.0      109.0
# 2       30.0       24.0        NaN        0.0      630.0      375.0
# 3       34.0       24.0        NaN        0.0      773.0      468.0
# 4       30.0       46.0        NaN        0.0      879.0      534.0
#
#    holed_998  holed_999  holed_1000
# 0       45.0      253.0       186.0
# 1       40.0      227.0       180.0
# 2       58.0      237.0       166.0
# 3       48.0      245.0       525.0
# 4       41.0      175.0       372.0
#
# [5 rows x 21001 columns]

# %%
y_train.head()
# Out:
#               Horodate  holed_1  holed_2  holed_3  holed_4  holed_5  holed_6  \
# 0  2023-01-09 00:00:00    578.0    698.0     17.0      2.0    283.0    154.0
# 1  2023-01-09 00:30:00    533.0    224.0     18.0      2.0   1047.0    150.0
# 2  2023-01-09 01:00:00    623.0    246.0     17.0      5.0   1185.0    131.0
# 3  2023-01-09 01:30:00    613.0    643.0     17.0     18.0    746.0     77.0
# 4  2023-01-09 02:00:00   1823.0    318.0     18.0     15.0    560.0    125.0
#
#    holed_7  holed_8  holed_9  ...  holed_991  holed_992  holed_993  holed_994  \
# 0    131.0    619.0    107.0  ...        0.0       32.0      152.0      121.0
# 1    106.0    542.0    114.0  ...        0.0       34.0       84.0      107.0
# 2     74.0    517.0    109.0  ...        0.0       30.0       24.0      128.0
# 3    146.0    455.0    113.0  ...        0.0       34.0       24.0      200.0
# 4     82.0    551.0    104.0  ...        0.0       30.0       46.0      792.0
#
#    holed_995  holed_996  holed_997  holed_998  holed_999  holed_1000
# 0        0.0     1099.0      117.0       45.0      253.0       186.0
# 1        0.0      782.0      109.0       40.0      227.0       180.0
# 2        0.0      630.0      375.0       58.0      237.0       166.0
# 3        0.0      773.0      468.0       48.0      245.0       525.0
# 4        0.0      879.0      534.0       41.0      175.0       372.0
#
# [5 rows x 1001 columns]

# %%
X_test.head()
# Out:
#               Horodate  123476859  123596487  123798654  123875946  123879645  \
# 0  2023-01-09 00:00:00      102.0      992.0      365.0      252.0       71.0
# 1  2023-01-09 00:30:00       89.0      996.0      351.0      219.0       47.0
# 2  2023-01-09 01:00:00      134.0      841.0      314.0      213.0       55.0
# 3  2023-01-09 01:30:00      130.0      961.0      228.0      253.0       35.0
# 4  2023-01-09 02:00:00      135.0      949.0      213.0      243.0       47.0
#
#    123897645  123947865  124367958  124568973  ...  holed_991  holed_992  \
# 0      132.0       30.0      201.0      121.0  ...       38.0      168.0
# 1      140.0       31.0      173.0      186.0  ...       27.0       82.0
# 2      114.0       38.0      204.0      251.0  ...       37.0      102.0
# 3      103.0       35.0      176.0      305.0  ...       13.0       78.0
# 4      472.0       21.0      187.0      283.0  ...       62.0      107.0
#
#    holed_993  holed_994  holed_995  holed_996  holed_997  holed_998  \
# 0       32.0        NaN      445.0        NaN        NaN      767.0
# 1       48.0        NaN      492.0      207.0        NaN      773.0
# 2       44.0        NaN      461.0      218.0        NaN      613.0
# 3       33.0        NaN      491.0      104.0        NaN      691.0
# 4       36.0        NaN      451.0       97.0        NaN      844.0
#
#    holed_999  holed_1000
# 0     2029.0       129.0
# 1     1698.0       113.0
# 2     1737.0         NaN
# 3      994.0       135.0
# 4     1044.0         NaN
#
# [5 rows x 38141 columns]

# %% [markdown]
# On va extraire les colonnes holed_, c'est à dire celles avec des trous, on va drop holed_192 car elle est vide dans X et Y train

# %%
holed = [col for col in X_train.columns if col.startswith('holed_') and not col.startswith('holed_192')]

# %%
no_holes = [col for col in X_train.columns if not col.startswith('holed_')]
holed = [col for col in X_train.columns if col.startswith('holed_') and not col.startswith('holed_192')]


X_train = X_train.drop(columns=['holed_192'])
y_train  = y_train.drop(columns=['holed_192'])

# %% [markdown]
# On observe la présence de NaN dans les no_holes uniquement sur la colonnes 7986541023 où otut est à 0 sauf 620 NaN, on les remplacera juste par des 0

# %%
X_train[holed]=y_train[holed].copy()
row_with_nan=X_train[X_train[no_holes].isna().any(axis=1)]
row_with_nan
print(len(row_with_nan))
col_with_nan=X_train.columns[X_train.isna().any()]
(X_train[col_with_nan]).sum()
# Out:
# 620
# 7986541023    0.0
# dtype: float64

# %% [markdown]
# Pour commencer, on a besoin de gérer la variable quantitative de l'Horodate, grâce à panda, on peut aisément la siviser en années, mois, jours, heure et jour de la semaine, qui peuvent être des données utile pouir la régression.
#
# Ensuite, on va combler les NaN avec les moyenne des colonnes, pour ne pas perdre les datas des autres colonnes et éviter d'impacter la moyenne.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

X_train_nodate = X_train.copy()
X_test_nodate = X_test.copy()
y_train_nodate = y_train.copy()

X_train_nodate['Horodate'] = pd.to_datetime(X_train_nodate['Horodate'])
X_test_nodate['Horodate'] = pd.to_datetime(X_test_nodate['Horodate'])
y_train_nodate['Horodate'] = pd.to_datetime(y_train_nodate['Horodate'])


for df in [X_train_nodate, X_test_nodate]:
    df['year'] = df['Horodate'].dt.year
    df['month'] = df['Horodate'].dt.month
    df['day'] = df['Horodate'].dt.day
    df['hour'] = df['Horodate'].dt.hour
    df['weekday'] = df['Horodate'].dt.weekday



X_train_nodate = X_train_nodate.drop(columns=['Horodate'])
X_test_nodate = X_test_nodate.drop(columns=['Horodate'])
y_train_nodate = y_train_nodate.drop(columns=['Horodate'])


X_train_filled = X_train_nodate.copy()

X_test_filled = X_test_nodate.copy()

X_train_filled["7986541023"] = X_train_filled["7986541023"].fillna(0)
X_train_filled = X_train_filled.drop(columns=holed)

#X_test_filled  = X_test_nodate.fillna(X_test_nodate.mean())

# %%
""" scaler = StandardScaler()
X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train_filled), 
    columns=X_train_filled.columns, 
    index=X_train_filled.index)

X_test_scaled = pd.DataFrame(
    scaler.transform(X_test_filled),
    columns=X_test_filled.columns,
    index=X_test_filled.index) """


X_test_filled.head()
# Out:
#    123476859  123596487  123798654  123875946  123879645  123897645  \
# 0      102.0      992.0      365.0      252.0       71.0      132.0
# 1       89.0      996.0      351.0      219.0       47.0      140.0
# 2      134.0      841.0      314.0      213.0       55.0      114.0
# 3      130.0      961.0      228.0      253.0       35.0      103.0
# 4      135.0      949.0      213.0      243.0       47.0      472.0
#
#    123947865  124367958  124568973  124589367  ...  holed_996  holed_997  \
# 0       30.0      201.0      121.0       55.0  ...        NaN        NaN
# 1       31.0      173.0      186.0       82.0  ...      207.0        NaN
# 2       38.0      204.0      251.0       86.0  ...      218.0        NaN
# 3       35.0      176.0      305.0       44.0  ...      104.0        NaN
# 4       21.0      187.0      283.0       75.0  ...       97.0        NaN
#
#    holed_998  holed_999  holed_1000  year  month  day  hour  weekday
# 0      767.0     2029.0       129.0  2023      1    9     0        0
# 1      773.0     1698.0       113.0  2023      1    9     0        0
# 2      613.0     1737.0         NaN  2023      1    9     1        0
# 3      691.0      994.0       135.0  2023      1    9     1        0
# 4      844.0     1044.0         NaN  2023      1    9     2        0
#
# [5 rows x 38145 columns]

# %%
models = {}
pred_list = []
columns_done = 0
r2 = []

X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_filled, y_train_nodate, test_size=0.2, random_state=42
)

for col in holed:
    #mask = ~y_train_nodate[col].isna()
    #X = X_train_filled.loc[mask, :]
    #y = y_train_nodate.loc[mask, col]

    X_subset = X_train_split.loc[:, X_train_split.columns != col]
    X_subset_val = X_val_split.loc[:, X_val_split.columns != col]

    X = X_subset
    y = y_train_split[col]

    model = LinearRegression()
    model.fit(X, y)
    models[col] = model

    pred = pd.DataFrame(model.predict(X_subset_val), columns=[col], index=X_subset_val.index)
    pred_list.append(pred)

    columns_done+=1
    print(columns_done, "ème colonne a été estimée")
    r2.append(r2_score(y_val_split[col], pred))


y_pred = pd.concat(pred_list, axis=1)
# Out:
# 1 ème colonne a été estimée
# 2 ème colonne a été estimée
# 3 ème colonne a été estimée
# 4 ème colonne a été estimée
# 5 ème colonne a été estimée
# 6 ème colonne a été estimée
# 7 ème colonne a été estimée
# 8 ème colonne a été estimée
# 9 ème colonne a été estimée
# 10 ème colonne a été estimée
# 11 ème colonne a été estimée
# 12 ème colonne a été estimée
# 13 ème colonne a été estimée
# 14 ème colonne a été estimée
# 15 ème colonne a été estimée
# 16 ème colonne a été estimée
# 17 ème colonne a été estimée
# 18 ème colonne a été estimée
# 19 ème colonne a été estimée
# 20 ème colonne a été estimée
# 21 ème colonne a été estimée
# 22 ème colonne a été estimée
# 23 ème colonne a été estimée
# 24 ème colonne a été estimée
# 25 ème colonne a été estimée
# 26 ème colonne a été estimée
# 27 ème colonne a été estimée
# 28 ème colonne a été estimée
# 29 ème colonne a été estimée
# 30 ème colonne a été estimée
# 31 ème colonne a été estimée
# 32 ème colonne a été estimée
# 33 ème colonne a été estimée
# 34 ème colonne a été estimée
# 35 ème colonne a été estimée
# 36 ème colonne a été estimée
# 37 ème colonne a été estimée
# 38 ème colonne a été estimée
# 39 ème colonne a été estimée
# 40 ème colonne a été estimée
# 41 ème colonne a été estimée
# 42 ème colonne a été estimée
# 43 ème colonne a été estimée
# 44 ème colonne a été estimée
# 45 ème colonne a été estimée
# 46 ème colonne a été estimée
# 47 ème colonne a été estimée
# 48 ème colonne a été estimée
# 49 ème colonne a été estimée
# 50 ème colonne a été estimée
# 51 ème colonne a été estimée
# 52 ème colonne a été estimée
# 53 ème colonne a été estimée
# 54 ème colonne a été estimée
# 55 ème colonne a été estimée
# 56 ème colonne a été estimée
# 57 ème colonne a été estimée
# 58 ème colonne a été estimée
# 59 ème colonne a été estimée
# 60 ème colonne a été estimée
# 61 ème colonne a été estimée
# 62 ème colonne a été estimée
# 63 ème colonne a été estimée
# 64 ème colonne a été estimée
# 65 ème colonne a été estimée
# 66 ème colonne a été estimée
# 67 ème colonne a été estimée
# 68 ème colonne a été estimée
# 69 ème colonne a été estimée
# 70 ème colonne a été estimée
# 71 ème colonne a été estimée
# 72 ème colonne a été estimée
# 73 ème colonne a été estimée
# 74 ème colonne a été estimée
# 75 ème colonne a été estimée
# 76 ème colonne a été estimée
# 77 ème colonne a été estimée
# 78 ème colonne a été estimée
# 79 ème colonne a été estimée
# 80 ème colonne a été estimée
# 81 ème colonne a été estimée
# 82 ème colonne a été estimée
# 83 ème colonne a été estimée
# 84 ème colonne a été estimée
# 85 ème colonne a été estimée
# 86 ème colonne a été estimée
# 87 ème colonne a été estimée
# 88 ème colonne a été estimée
# 89 ème colonne a été estimée
# 90 ème colonne a été estimée
# 91 ème colonne a été estimée
# 92 ème colonne a été estimée
# 93 ème colonne a été estimée
# 94 ème colonne a été estimée
# 95 ème colonne a été estimée
# 96 ème colonne a été estimée
# 97 ème colonne a été estimée
# 98 ème colonne a été estimée
# 99 ème colonne a été estimée
# 100 ème colonne a été estimée
# 101 ème colonne a été estimée
# 102 ème colonne a été estimée
# 103 ème colonne a été estimée
# 104 ème colonne a été estimée
# 105 ème colonne a été estimée
# 106 ème colonne a été estimée
# 107 ème colonne a été estimée
# 108 ème colonne a été estimée
# 109 ème colonne a été estimée
# 110 ème colonne a été estimée
# 111 ème colonne a été estimée
# 112 ème colonne a été estimée
# 113 ème colonne a été estimée
# 114 ème colonne a été estimée
# 115 ème colonne a été estimée
# 116 ème colonne a été estimée
# 117 ème colonne a été estimée
# 118 ème colonne a été estimée
# 119 ème colonne a été estimée
# 120 ème colonne a été estimée
# 121 ème colonne a été estimée
# 122 ème colonne a été estimée
# 123 ème colonne a été estimée
# 124 ème colonne a été estimée
# 125 ème colonne a été estimée
# 126 ème colonne a été estimée
# 127 ème colonne a été estimée
# 128 ème colonne a été estimée
# 129 ème colonne a été estimée
# 130 ème colonne a été estimée
# 131 ème colonne a été estimée
# 132 ème colonne a été estimée
# 133 ème colonne a été estimée
# 134 ème colonne a été estimée
# 135 ème colonne a été estimée
# 136 ème colonne a été estimée
# 137 ème colonne a été estimée
# 138 ème colonne a été estimée
# 139 ème colonne a été estimée
# 140 ème colonne a été estimée
# 141 ème colonne a été estimée
# 142 ème colonne a été estimée
# 143 ème colonne a été estimée
# 144 ème colonne a été estimée
# 145 ème colonne a été estimée
# 146 ème colonne a été estimée
# 147 ème colonne a été estimée
# 148 ème colonne a été estimée
# 149 ème colonne a été estimée
# 150 ème colonne a été estimée
# 151 ème colonne a été estimée
# 152 ème colonne a été estimée
# 153 ème colonne a été estimée
# 154 ème colonne a été estimée
# 155 ème colonne a été estimée
# 156 ème colonne a été estimée
# 157 ème colonne a été estimée
# 158 ème colonne a été estimée
# 159 ème colonne a été estimée
# 160 ème colonne a été estimée
# 161 ème colonne a été estimée
# 162 ème colonne a été estimée
# 163 ème colonne a été estimée
# 164 ème colonne a été estimée
# 165 ème colonne a été estimée
# 166 ème colonne a été estimée
# 167 ème colonne a été estimée
# 168 ème colonne a été estimée
# 169 ème colonne a été estimée
# 170 ème colonne a été estimée
# 171 ème colonne a été estimée
# 172 ème colonne a été estimée
# 173 ème colonne a été estimée
# 174 ème colonne a été estimée
# 175 ème colonne a été estimée
# 176 ème colonne a été estimée
# 177 ème colonne a été estimée
# 178 ème colonne a été estimée
# 179 ème colonne a été estimée
# 180 ème colonne a été estimée
# 181 ème colonne a été estimée
# 182 ème colonne a été estimée
# 183 ème colonne a été estimée
# 184 ème colonne a été estimée
# 185 ème colonne a été estimée
# 186 ème colonne a été estimée
# 187 ème colonne a été estimée
# 188 ème colonne a été estimée
# 189 ème colonne a été estimée
# 190 ème colonne a été estimée
# 191 ème colonne a été estimée
# 192 ème colonne a été estimée
# 193 ème colonne a été estimée
# 194 ème colonne a été estimée
# 195 ème colonne a été estimée
# 196 ème colonne a été estimée
# 197 ème colonne a été estimée
# 198 ème colonne a été estimée
# 199 ème colonne a été estimée
# 200 ème colonne a été estimée
# 201 ème colonne a été estimée
# 202 ème colonne a été estimée
# 203 ème colonne a été estimée
# 204 ème colonne a été estimée
# 205 ème colonne a été estimée
# 206 ème colonne a été estimée
# 207 ème colonne a été estimée
# 208 ème colonne a été estimée
# 209 ème colonne a été estimée
# 210 ème colonne a été estimée
# 211 ème colonne a été estimée
# 212 ème colonne a été estimée
# 213 ème colonne a été estimée
# 214 ème colonne a été estimée
# 215 ème colonne a été estimée
# 216 ème colonne a été estimée
# 217 ème colonne a été estimée
# 218 ème colonne a été estimée
# 219 ème colonne a été estimée
# 220 ème colonne a été estimée
# 221 ème colonne a été estimée
# 222 ème colonne a été estimée
# 223 ème colonne a été estimée
# 224 ème colonne a été estimée
# 225 ème colonne a été estimée
# 226 ème colonne a été estimée
# 227 ème colonne a été estimée
# 228 ème colonne a été estimée
# 229 ème colonne a été estimée
# 230 ème colonne a été estimée
# 231 ème colonne a été estimée
# 232 ème colonne a été estimée
# 233 ème colonne a été estimée
# 234 ème colonne a été estimée
# 235 ème colonne a été estimée
# 236 ème colonne a été estimée
# 237 ème colonne a été estimée
# 238 ème colonne a été estimée
# 239 ème colonne a été estimée
# 240 ème colonne a été estimée
# 241 ème colonne a été estimée
# 242 ème colonne a été estimée
# 243 ème colonne a été estimée
# 244 ème colonne a été estimée
# 245 ème colonne a été estimée
# 246 ème colonne a été estimée
# 247 ème colonne a été estimée
# 248 ème colonne a été estimée
# 249 ème colonne a été estimée
# 250 ème colonne a été estimée
# 251 ème colonne a été estimée
# 252 ème colonne a été estimée
# 253 ème colonne a été estimée
# 254 ème colonne a été estimée
# 255 ème colonne a été estimée
# 256 ème colonne a été estimée
# 257 ème colonne a été estimée
# 258 ème colonne a été estimée
# 259 ème colonne a été estimée
# 260 ème colonne a été estimée
# 261 ème colonne a été estimée
# 262 ème colonne a été estimée
# 263 ème colonne a été estimée
# 264 ème colonne a été estimée
# 265 ème colonne a été estimée
# 266 ème colonne a été estimée
# 267 ème colonne a été estimée
# 268 ème colonne a été estimée
# 269 ème colonne a été estimée
# 270 ème colonne a été estimée
# 271 ème colonne a été estimée
# 272 ème colonne a été estimée
# 273 ème colonne a été estimée
# 274 ème colonne a été estimée
# 275 ème colonne a été estimée
# 276 ème colonne a été estimée
# 277 ème colonne a été estimée
# 278 ème colonne a été estimée
# 279 ème colonne a été estimée
# 280 ème colonne a été estimée
# 281 ème colonne a été estimée
# 282 ème colonne a été estimée
# 283 ème colonne a été estimée
# 284 ème colonne a été estimée
# 285 ème colonne a été estimée
# 286 ème colonne a été estimée
# 287 ème colonne a été estimée
# 288 ème colonne a été estimée
# 289 ème colonne a été estimée
# 290 ème colonne a été estimée
# 291 ème colonne a été estimée
# 292 ème colonne a été estimée
# 293 ème colonne a été estimée
# 294 ème colonne a été estimée
# 295 ème colonne a été estimée
# 296 ème colonne a été estimée
# 297 ème colonne a été estimée
# 298 ème colonne a été estimée
# 299 ème colonne a été estimée
# 300 ème colonne a été estimée
# 301 ème colonne a été estimée
# 302 ème colonne a été estimée
# 303 ème colonne a été estimée
# 304 ème colonne a été estimée
# 305 ème colonne a été estimée
# 306 ème colonne a été estimée
# 307 ème colonne a été estimée
# 308 ème colonne a été estimée
# 309 ème colonne a été estimée
# 310 ème colonne a été estimée
# 311 ème colonne a été estimée
# 312 ème colonne a été estimée
# 313 ème colonne a été estimée
# 314 ème colonne a été estimée
# 315 ème colonne a été estimée
# 316 ème colonne a été estimée
# 317 ème colonne a été estimée
# 318 ème colonne a été estimée
# 319 ème colonne a été estimée
# 320 ème colonne a été estimée
# 321 ème colonne a été estimée
# 322 ème colonne a été estimée
# 323 ème colonne a été estimée
# 324 ème colonne a été estimée
# 325 ème colonne a été estimée
# 326 ème colonne a été estimée
# 327 ème colonne a été estimée
# 328 ème colonne a été estimée
# 329 ème colonne a été estimée
# 330 ème colonne a été estimée
# 331 ème colonne a été estimée
# 332 ème colonne a été estimée
# 333 ème colonne a été estimée
# 334 ème colonne a été estimée
# 335 ème colonne a été estimée
# 336 ème colonne a été estimée
# 337 ème colonne a été estimée
# 338 ème colonne a été estimée
# 339 ème colonne a été estimée
# 340 ème colonne a été estimée
# 341 ème colonne a été estimée
# 342 ème colonne a été estimée
# 343 ème colonne a été estimée
# 344 ème colonne a été estimée
# 345 ème colonne a été estimée
# 346 ème colonne a été estimée
# 347 ème colonne a été estimée
# 348 ème colonne a été estimée
# 349 ème colonne a été estimée
# 350 ème colonne a été estimée
# 351 ème colonne a été estimée
# 352 ème colonne a été estimée
# 353 ème colonne a été estimée
# 354 ème colonne a été estimée
# 355 ème colonne a été estimée
# 356 ème colonne a été estimée
# 357 ème colonne a été estimée
# 358 ème colonne a été estimée
# 359 ème colonne a été estimée
# 360 ème colonne a été estimée
# 361 ème colonne a été estimée
# 362 ème colonne a été estimée
# 363 ème colonne a été estimée
# 364 ème colonne a été estimée
# 365 ème colonne a été estimée
# 366 ème colonne a été estimée
# 367 ème colonne a été estimée
# 368 ème colonne a été estimée
# 369 ème colonne a été estimée
# 370 ème colonne a été estimée
# 371 ème colonne a été estimée
# 372 ème colonne a été estimée
# 373 ème colonne a été estimée
# 374 ème colonne a été estimée
# 375 ème colonne a été estimée
# 376 ème colonne a été estimée
# 377 ème colonne a été estimée
# 378 ème colonne a été estimée
# 379 ème colonne a été estimée
# 380 ème colonne a été estimée
# 381 ème colonne a été estimée
# 382 ème colonne a été estimée
# 383 ème colonne a été estimée
# 384 ème colonne a été estimée
# 385 ème colonne a été estimée
# 386 ème colonne a été estimée
# 387 ème colonne a été estimée
# 388 ème colonne a été estimée
# 389 ème colonne a été estimée
# 390 ème colonne a été estimée
# 391 ème colonne a été estimée
# 392 ème colonne a été estimée
# 393 ème colonne a été estimée
# 394 ème colonne a été estimée
# 395 ème colonne a été estimée
# 396 ème colonne a été estimée
# 397 ème colonne a été estimée
# 398 ème colonne a été estimée
# 399 ème colonne a été estimée
# 400 ème colonne a été estimée
# 401 ème colonne a été estimée
# 402 ème colonne a été estimée
# 403 ème colonne a été estimée
# 404 ème colonne a été estimée
# 405 ème colonne a été estimée
# 406 ème colonne a été estimée
# 407 ème colonne a été estimée
# 408 ème colonne a été estimée
# 409 ème colonne a été estimée
# 410 ème colonne a été estimée
# 411 ème colonne a été estimée
# 412 ème colonne a été estimée
# 413 ème colonne a été estimée
# 414 ème colonne a été estimée
# 415 ème colonne a été estimée
# 416 ème colonne a été estimée
# 417 ème colonne a été estimée
# 418 ème colonne a été estimée
# 419 ème colonne a été estimée
# 420 ème colonne a été estimée
# 421 ème colonne a été estimée
# 422 ème colonne a été estimée
# 423 ème colonne a été estimée
# 424 ème colonne a été estimée
# 425 ème colonne a été estimée
# 426 ème colonne a été estimée
# 427 ème colonne a été estimée
# 428 ème colonne a été estimée
# 429 ème colonne a été estimée
# 430 ème colonne a été estimée
# 431 ème colonne a été estimée
# 432 ème colonne a été estimée
# 433 ème colonne a été estimée
# 434 ème colonne a été estimée
# 435 ème colonne a été estimée
# 436 ème colonne a été estimée
# 437 ème colonne a été estimée
# 438 ème colonne a été estimée
# 439 ème colonne a été estimée
# 440 ème colonne a été estimée
# 441 ème colonne a été estimée
# 442 ème colonne a été estimée
# 443 ème colonne a été estimée
# 444 ème colonne a été estimée
# 445 ème colonne a été estimée
# 446 ème colonne a été estimée
# 447 ème colonne a été estimée
# 448 ème colonne a été estimée
# 449 ème colonne a été estimée
# 450 ème colonne a été estimée
# 451 ème colonne a été estimée
# 452 ème colonne a été estimée
# 453 ème colonne a été estimée
# 454 ème colonne a été estimée
# 455 ème colonne a été estimée
# 456 ème colonne a été estimée
# 457 ème colonne a été estimée
# 458 ème colonne a été estimée
# 459 ème colonne a été estimée
# 460 ème colonne a été estimée
# 461 ème colonne a été estimée
# 462 ème colonne a été estimée
# 463 ème colonne a été estimée
# 464 ème colonne a été estimée
# 465 ème colonne a été estimée
# 466 ème colonne a été estimée
# 467 ème colonne a été estimée
# 468 ème colonne a été estimée
# 469 ème colonne a été estimée
# 470 ème colonne a été estimée
# 471 ème colonne a été estimée
# 472 ème colonne a été estimée
# 473 ème colonne a été estimée
# 474 ème colonne a été estimée
# 475 ème colonne a été estimée
# 476 ème colonne a été estimée
# 477 ème colonne a été estimée
# 478 ème colonne a été estimée
# 479 ème colonne a été estimée
# 480 ème colonne a été estimée
# 481 ème colonne a été estimée
# 482 ème colonne a été estimée
# 483 ème colonne a été estimée
# 484 ème colonne a été estimée
# 485 ème colonne a été estimée
# 486 ème colonne a été estimée
# 487 ème colonne a été estimée
# 488 ème colonne a été estimée
# 489 ème colonne a été estimée
# 490 ème colonne a été estimée
# 491 ème colonne a été estimée
# 492 ème colonne a été estimée
# 493 ème colonne a été estimée
# 494 ème colonne a été estimée
# 495 ème colonne a été estimée
# 496 ème colonne a été estimée
# 497 ème colonne a été estimée
# 498 ème colonne a été estimée
# 499 ème colonne a été estimée
# 500 ème colonne a été estimée
# 501 ème colonne a été estimée
# 502 ème colonne a été estimée
# 503 ème colonne a été estimée
# 504 ème colonne a été estimée
# 505 ème colonne a été estimée
# 506 ème colonne a été estimée
# 507 ème colonne a été estimée
# 508 ème colonne a été estimée
# 509 ème colonne a été estimée
# 510 ème colonne a été estimée
# 511 ème colonne a été estimée
# 512 ème colonne a été estimée
# 513 ème colonne a été estimée
# 514 ème colonne a été estimée
# 515 ème colonne a été estimée
# 516 ème colonne a été estimée
# 517 ème colonne a été estimée
# 518 ème colonne a été estimée
# 519 ème colonne a été estimée
# 520 ème colonne a été estimée
# 521 ème colonne a été estimée
# 522 ème colonne a été estimée
# 523 ème colonne a été estimée
# 524 ème colonne a été estimée
# 525 ème colonne a été estimée
# 526 ème colonne a été estimée
# 527 ème colonne a été estimée
# 528 ème colonne a été estimée
# 529 ème colonne a été estimée
# 530 ème colonne a été estimée
# 531 ème colonne a été estimée
# 532 ème colonne a été estimée
# 533 ème colonne a été estimée
# 534 ème colonne a été estimée
# 535 ème colonne a été estimée
# 536 ème colonne a été estimée
# 537 ème colonne a été estimée
# 538 ème colonne a été estimée
# 539 ème colonne a été estimée
# 540 ème colonne a été estimée
# 541 ème colonne a été estimée
# 542 ème colonne a été estimée
# 543 ème colonne a été estimée
# 544 ème colonne a été estimée
# 545 ème colonne a été estimée
# 546 ème colonne a été estimée
# 547 ème colonne a été estimée
# 548 ème colonne a été estimée
# 549 ème colonne a été estimée
# 550 ème colonne a été estimée
# 551 ème colonne a été estimée
# 552 ème colonne a été estimée
# 553 ème colonne a été estimée
# 554 ème colonne a été estimée
# 555 ème colonne a été estimée
# 556 ème colonne a été estimée
# 557 ème colonne a été estimée
# 558 ème colonne a été estimée
# 559 ème colonne a été estimée
# 560 ème colonne a été estimée
# 561 ème colonne a été estimée
# 562 ème colonne a été estimée
# 563 ème colonne a été estimée
# 564 ème colonne a été estimée
# 565 ème colonne a été estimée
# 566 ème colonne a été estimée
# 567 ème colonne a été estimée
# 568 ème colonne a été estimée
# 569 ème colonne a été estimée
# 570 ème colonne a été estimée
# 571 ème colonne a été estimée
# 572 ème colonne a été estimée
# 573 ème colonne a été estimée
# 574 ème colonne a été estimée
# 575 ème colonne a été estimée
# 576 ème colonne a été estimée
# 577 ème colonne a été estimée
# 578 ème colonne a été estimée
# 579 ème colonne a été estimée
# 580 ème colonne a été estimée
# 581 ème colonne a été estimée
# 582 ème colonne a été estimée
# 583 ème colonne a été estimée
# 584 ème colonne a été estimée
# 585 ème colonne a été estimée
# 586 ème colonne a été estimée
# 587 ème colonne a été estimée
# 588 ème colonne a été estimée
# 589 ème colonne a été estimée
# 590 ème colonne a été estimée
# 591 ème colonne a été estimée
# 592 ème colonne a été estimée
# 593 ème colonne a été estimée
# 594 ème colonne a été estimée
# 595 ème colonne a été estimée
# 596 ème colonne a été estimée
# 597 ème colonne a été estimée
# 598 ème colonne a été estimée
# 599 ème colonne a été estimée
# 600 ème colonne a été estimée
# 601 ème colonne a été estimée
# 602 ème colonne a été estimée
# 603 ème colonne a été estimée
# 604 ème colonne a été estimée
# 605 ème colonne a été estimée
# 606 ème colonne a été estimée
# 607 ème colonne a été estimée
# 608 ème colonne a été estimée
# 609 ème colonne a été estimée
# 610 ème colonne a été estimée
# 611 ème colonne a été estimée
# 612 ème colonne a été estimée
# 613 ème colonne a été estimée
# 614 ème colonne a été estimée
# 615 ème colonne a été estimée
# 616 ème colonne a été estimée
# 617 ème colonne a été estimée
# 618 ème colonne a été estimée
# 619 ème colonne a été estimée
# 620 ème colonne a été estimée
# 621 ème colonne a été estimée
# 622 ème colonne a été estimée
# 623 ème colonne a été estimée
# 624 ème colonne a été estimée
# 625 ème colonne a été estimée
# 626 ème colonne a été estimée
# 627 ème colonne a été estimée
# 628 ème colonne a été estimée
# 629 ème colonne a été estimée
# 630 ème colonne a été estimée
# 631 ème colonne a été estimée
# 632 ème colonne a été estimée
# 633 ème colonne a été estimée
# 634 ème colonne a été estimée
# 635 ème colonne a été estimée
# 636 ème colonne a été estimée
# 637 ème colonne a été estimée
# 638 ème colonne a été estimée
# 639 ème colonne a été estimée
# 640 ème colonne a été estimée
# 641 ème colonne a été estimée
# 642 ème colonne a été estimée
# 643 ème colonne a été estimée
# 644 ème colonne a été estimée
# 645 ème colonne a été estimée
# 646 ème colonne a été estimée
# 647 ème colonne a été estimée
# 648 ème colonne a été estimée
# 649 ème colonne a été estimée
# 650 ème colonne a été estimée
# 651 ème colonne a été estimée
# 652 ème colonne a été estimée
# 653 ème colonne a été estimée
# 654 ème colonne a été estimée
# 655 ème colonne a été estimée
# 656 ème colonne a été estimée
# 657 ème colonne a été estimée
# 658 ème colonne a été estimée
# 659 ème colonne a été estimée
# 660 ème colonne a été estimée
# 661 ème colonne a été estimée
# 662 ème colonne a été estimée
# 663 ème colonne a été estimée
# 664 ème colonne a été estimée
# 665 ème colonne a été estimée
# 666 ème colonne a été estimée
# 667 ème colonne a été estimée
# 668 ème colonne a été estimée
# 669 ème colonne a été estimée
# 670 ème colonne a été estimée
# 671 ème colonne a été estimée
# 672 ème colonne a été estimée
# 673 ème colonne a été estimée
# 674 ème colonne a été estimée
# 675 ème colonne a été estimée
# 676 ème colonne a été estimée
# 677 ème colonne a été estimée
# 678 ème colonne a été estimée
# 679 ème colonne a été estimée
# 680 ème colonne a été estimée
# 681 ème colonne a été estimée
# 682 ème colonne a été estimée
# 683 ème colonne a été estimée
# 684 ème colonne a été estimée
# 685 ème colonne a été estimée
# 686 ème colonne a été estimée
# 687 ème colonne a été estimée
# 688 ème colonne a été estimée
# 689 ème colonne a été estimée
# 690 ème colonne a été estimée
# 691 ème colonne a été estimée
# 692 ème colonne a été estimée
# 693 ème colonne a été estimée
# 694 ème colonne a été estimée
# 695 ème colonne a été estimée
# 696 ème colonne a été estimée
# 697 ème colonne a été estimée
# 698 ème colonne a été estimée
# 699 ème colonne a été estimée
# 700 ème colonne a été estimée
# 701 ème colonne a été estimée
# 702 ème colonne a été estimée
# 703 ème colonne a été estimée
# 704 ème colonne a été estimée
# 705 ème colonne a été estimée
# 706 ème colonne a été estimée
# 707 ème colonne a été estimée
# 708 ème colonne a été estimée
# 709 ème colonne a été estimée
# 710 ème colonne a été estimée
# 711 ème colonne a été estimée
# 712 ème colonne a été estimée
# 713 ème colonne a été estimée
# 714 ème colonne a été estimée
# 715 ème colonne a été estimée
# 716 ème colonne a été estimée
# 717 ème colonne a été estimée
# 718 ème colonne a été estimée
# 719 ème colonne a été estimée
# 720 ème colonne a été estimée
# 721 ème colonne a été estimée
# 722 ème colonne a été estimée
# 723 ème colonne a été estimée
# 724 ème colonne a été estimée
# 725 ème colonne a été estimée
# 726 ème colonne a été estimée
# 727 ème colonne a été estimée
# 728 ème colonne a été estimée
# 729 ème colonne a été estimée
# 730 ème colonne a été estimée
# 731 ème colonne a été estimée
# 732 ème colonne a été estimée
# 733 ème colonne a été estimée
# 734 ème colonne a été estimée
# 735 ème colonne a été estimée
# 736 ème colonne a été estimée
# 737 ème colonne a été estimée
# 738 ème colonne a été estimée
# 739 ème colonne a été estimée
# 740 ème colonne a été estimée
# 741 ème colonne a été estimée
# 742 ème colonne a été estimée
# 743 ème colonne a été estimée
# 744 ème colonne a été estimée
# 745 ème colonne a été estimée
# 746 ème colonne a été estimée
# 747 ème colonne a été estimée
# 748 ème colonne a été estimée
# 749 ème colonne a été estimée
# 750 ème colonne a été estimée
# 751 ème colonne a été estimée
# 752 ème colonne a été estimée
# 753 ème colonne a été estimée
# 754 ème colonne a été estimée
# 755 ème colonne a été estimée
# 756 ème colonne a été estimée
# 757 ème colonne a été estimée
# 758 ème colonne a été estimée
# 759 ème colonne a été estimée
# 760 ème colonne a été estimée
# 761 ème colonne a été estimée
# 762 ème colonne a été estimée
# 763 ème colonne a été estimée
# 764 ème colonne a été estimée
# 765 ème colonne a été estimée
# 766 ème colonne a été estimée
# 767 ème colonne a été estimée
# 768 ème colonne a été estimée
# 769 ème colonne a été estimée
# 770 ème colonne a été estimée
# 771 ème colonne a été estimée
# 772 ème colonne a été estimée
# 773 ème colonne a été estimée
# 774 ème colonne a été estimée
# 775 ème colonne a été estimée
# 776 ème colonne a été estimée
# 777 ème colonne a été estimée
# 778 ème colonne a été estimée
# 779 ème colonne a été estimée
# 780 ème colonne a été estimée
# 781 ème colonne a été estimée
# 782 ème colonne a été estimée
# 783 ème colonne a été estimée
# 784 ème colonne a été estimée
# 785 ème colonne a été estimée
# 786 ème colonne a été estimée
# 787 ème colonne a été estimée
# 788 ème colonne a été estimée
# 789 ème colonne a été estimée
# 790 ème colonne a été estimée
# 791 ème colonne a été estimée
# 792 ème colonne a été estimée
# 793 ème colonne a été estimée
# 794 ème colonne a été estimée
# 795 ème colonne a été estimée
# 796 ème colonne a été estimée
# 797 ème colonne a été estimée
# 798 ème colonne a été estimée
# 799 ème colonne a été estimée
# 800 ème colonne a été estimée
# 801 ème colonne a été estimée
# 802 ème colonne a été estimée
# 803 ème colonne a été estimée
# 804 ème colonne a été estimée
# 805 ème colonne a été estimée
# 806 ème colonne a été estimée
# 807 ème colonne a été estimée
# 808 ème colonne a été estimée
# 809 ème colonne a été estimée
# 810 ème colonne a été estimée
# 811 ème colonne a été estimée
# 812 ème colonne a été estimée
# 813 ème colonne a été estimée
# 814 ème colonne a été estimée
# 815 ème colonne a été estimée
# 816 ème colonne a été estimée
# 817 ème colonne a été estimée
# 818 ème colonne a été estimée
# 819 ème colonne a été estimée
# 820 ème colonne a été estimée
# 821 ème colonne a été estimée
# 822 ème colonne a été estimée
# 823 ème colonne a été estimée
# 824 ème colonne a été estimée
# 825 ème colonne a été estimée
# 826 ème colonne a été estimée
# 827 ème colonne a été estimée
# 828 ème colonne a été estimée
# 829 ème colonne a été estimée
# 830 ème colonne a été estimée
# 831 ème colonne a été estimée
# 832 ème colonne a été estimée
# 833 ème colonne a été estimée
# 834 ème colonne a été estimée
# 835 ème colonne a été estimée
# 836 ème colonne a été estimée
# 837 ème colonne a été estimée
# 838 ème colonne a été estimée
# 839 ème colonne a été estimée
# 840 ème colonne a été estimée
# 841 ème colonne a été estimée
# 842 ème colonne a été estimée
# 843 ème colonne a été estimée
# 844 ème colonne a été estimée
# 845 ème colonne a été estimée
# 846 ème colonne a été estimée
# 847 ème colonne a été estimée
# 848 ème colonne a été estimée
# 849 ème colonne a été estimée
# 850 ème colonne a été estimée
# 851 ème colonne a été estimée
# 852 ème colonne a été estimée
# 853 ème colonne a été estimée
# 854 ème colonne a été estimée
# 855 ème colonne a été estimée
# 856 ème colonne a été estimée
# 857 ème colonne a été estimée
# 858 ème colonne a été estimée
# 859 ème colonne a été estimée
# 860 ème colonne a été estimée
# 861 ème colonne a été estimée
# 862 ème colonne a été estimée
# 863 ème colonne a été estimée
# 864 ème colonne a été estimée
# 865 ème colonne a été estimée
# 866 ème colonne a été estimée
# 867 ème colonne a été estimée
# 868 ème colonne a été estimée
# 869 ème colonne a été estimée
# 870 ème colonne a été estimée
# 871 ème colonne a été estimée
# 872 ème colonne a été estimée
# 873 ème colonne a été estimée
# 874 ème colonne a été estimée
# 875 ème colonne a été estimée
# 876 ème colonne a été estimée
# 877 ème colonne a été estimée
# 878 ème colonne a été estimée
# 879 ème colonne a été estimée
# 880 ème colonne a été estimée
# 881 ème colonne a été estimée
# 882 ème colonne a été estimée
# 883 ème colonne a été estimée
# 884 ème colonne a été estimée
# 885 ème colonne a été estimée
# 886 ème colonne a été estimée
# 887 ème colonne a été estimée
# 888 ème colonne a été estimée
# 889 ème colonne a été estimée
# 890 ème colonne a été estimée
# 891 ème colonne a été estimée
# 892 ème colonne a été estimée
# 893 ème colonne a été estimée
# 894 ème colonne a été estimée
# 895 ème colonne a été estimée
# 896 ème colonne a été estimée
# 897 ème colonne a été estimée
# 898 ème colonne a été estimée
# 899 ème colonne a été estimée
# 900 ème colonne a été estimée
# 901 ème colonne a été estimée
# 902 ème colonne a été estimée
# 903 ème colonne a été estimée
# 904 ème colonne a été estimée
# 905 ème colonne a été estimée
# 906 ème colonne a été estimée
# 907 ème colonne a été estimée
# 908 ème colonne a été estimée
# 909 ème colonne a été estimée
# 910 ème colonne a été estimée
# 911 ème colonne a été estimée
# 912 ème colonne a été estimée
# 913 ème colonne a été estimée
# 914 ème colonne a été estimée
# 915 ème colonne a été estimée
# 916 ème colonne a été estimée
# 917 ème colonne a été estimée
# 918 ème colonne a été estimée
# 919 ème colonne a été estimée
# 920 ème colonne a été estimée
# 921 ème colonne a été estimée
# 922 ème colonne a été estimée
# 923 ème colonne a été estimée
# 924 ème colonne a été estimée
# 925 ème colonne a été estimée
# 926 ème colonne a été estimée
# 927 ème colonne a été estimée
# 928 ème colonne a été estimée
# 929 ème colonne a été estimée
# 930 ème colonne a été estimée
# 931 ème colonne a été estimée
# 932 ème colonne a été estimée
# 933 ème colonne a été estimée
# 934 ème colonne a été estimée
# 935 ème colonne a été estimée
# 936 ème colonne a été estimée
# 937 ème colonne a été estimée
# 938 ème colonne a été estimée
# 939 ème colonne a été estimée
# 940 ème colonne a été estimée
# 941 ème colonne a été estimée
# 942 ème colonne a été estimée
# 943 ème colonne a été estimée
# 944 ème colonne a été estimée
# 945 ème colonne a été estimée
# 946 ème colonne a été estimée
# 947 ème colonne a été estimée
# 948 ème colonne a été estimée
# 949 ème colonne a été estimée
# 950 ème colonne a été estimée
# 951 ème colonne a été estimée
# 952 ème colonne a été estimée
# 953 ème colonne a été estimée
# 954 ème colonne a été estimée
# 955 ème colonne a été estimée
# 956 ème colonne a été estimée
# 957 ème colonne a été estimée
# 958 ème colonne a été estimée
# 959 ème colonne a été estimée
# 960 ème colonne a été estimée
# 961 ème colonne a été estimée
# 962 ème colonne a été estimée
# 963 ème colonne a été estimée
# 964 ème colonne a été estimée
# 965 ème colonne a été estimée
# 966 ème colonne a été estimée
# 967 ème colonne a été estimée
# 968 ème colonne a été estimée
# 969 ème colonne a été estimée
# 970 ème colonne a été estimée
# 971 ème colonne a été estimée
# 972 ème colonne a été estimée
# 973 ème colonne a été estimée
# 974 ème colonne a été estimée
# 975 ème colonne a été estimée
# 976 ème colonne a été estimée
# 977 ème colonne a été estimée
# 978 ème colonne a été estimée
# 979 ème colonne a été estimée
# 980 ème colonne a été estimée
# 981 ème colonne a été estimée
# 982 ème colonne a été estimée
# 983 ème colonne a été estimée
# 984 ème colonne a été estimée
# 985 ème colonne a été estimée
# 986 ème colonne a été estimée
# 987 ème colonne a été estimée
# 988 ème colonne a été estimée
# 989 ème colonne a été estimée
# 990 ème colonne a été estimée
# 991 ème colonne a été estimée
# 992 ème colonne a été estimée
# 993 ème colonne a été estimée
# 994 ème colonne a été estimée
# 995 ème colonne a été estimée
# 996 ème colonne a été estimée
# 997 ème colonne a été estimée
# 998 ème colonne a été estimée
# 999 ème colonne a été estimée

# %% [markdown]
# On applique le modele sur X_test

# %%
print(max(model.coef_))
coefs = model.coef_.ravel()
idx_max = np.argmax(coefs)
print(idx_max)
# Out:
# 0.007530966066950218
# 518

# %%
y_pred.to_csv('ypred_noholed.csv', index=False)

# %%
#y_val_split = y_val_split.fillna(y_val_split.mean())
#y_val_split=y_val_split.drop(columns=['year'])
#y_val_split=y_val_split.drop(columns=['day'])
#y_val_split=y_val_split.drop(columns=['hour'])
#y_val_split=y_val_split.drop(columns=['month'])
#y_val_split=y_val_split.drop(columns=['weekday'])

mae = mean_absolute_error(y_val_split, y_pred)
r2 = r2_score(y_val_split, y_pred)
#r2_mean = statistics.mean(r2)
print(f"MAE : {mae:.4f} ; R² : {r2:.4f}")

r2_per_col = r2_score(y_val_split, y_pred, multioutput='raw_values')
r2_mean = r2_score(y_val_split, y_pred)

print("R2 par colonne :", r2_per_col)
print("R2 moyen :", r2_mean)
print("Max R2 :", max(r2_per_col))
print("Min R2 :", min(r2_per_col))

print(min(model.coef_))
coefs = model.coef_.ravel()
idx_max = np.argmin(coefs)
print(idx_max)

#coefs_past1000 = []
#for i in range (999):
#    coefs_past1000.append(coefs[20000+i])
#coefs_past1000 = np.array(coefs_past1000)
#print("Somme des coeffs des holed :", coefs_past1000.sum())
#print("Max des coeffs de holed :", coefs_past1000.max())
# Out:
# MAE : 68.9031 ; R² : 0.3415
# R2 par colonne : [ 3.74404312e-01  2.63161933e-01  4.64954268e-01  6.48061521e-01
#   6.73613993e-01  3.48582753e-01  4.73475183e-01  3.84490230e-01
#   6.88343048e-01  7.80307644e-01  8.19465021e-01  9.13150316e-01
#   5.51996766e-01  8.89109286e-01  7.32845233e-01  2.69548564e-01
#   7.47074031e-01  4.04600788e-01  1.69335382e-01  6.70976363e-01
#   6.28462304e-01  5.07565734e-01  5.43273955e-01  7.07985049e-01
#  -1.67714698e-01  7.28678690e-01  5.83514752e-01  4.74263438e-01
#   3.97105622e-01  5.57531681e-01  5.89950167e-01  4.26024130e-01
